# %%
import os
import pandas as pd

# %%
# Define the directories
base_dir = "E:\\IEEE Sensor\\IEEE Sensor Xlsx Data"
folders = ["ECG_handled", "EEG_handled", "EMG_handled"]
merge_output_dir = "E:\\IEEE Sensor\\IEEE Sensor Xlsx Data\\Merge_data"

# Create the output directory if it doesn't exist
os.makedirs(merge_output_dir, exist_ok=True)

# Function to merge data for a specific subfolder name
def merge_data_for_subfolder(subfolder_name):
    data_dict = {}
    total_rows_before_merge = 0  # Variable to store total row count before merging
    eeg_row_counts = {}  # Dictionary to store row counts of EEG_handled subfolders

    # Loop through each base folder
    for folder in folders:
        folder_path = os.path.join(base_dir, folder)
        subfolder_path = os.path.join(folder_path, subfolder_name)
        if os.path.exists(subfolder_path):
            for file in os.listdir(subfolder_path):
                file_path = os.path.join(subfolder_path, file)
                if file.endswith(".xlsx"):
                    try:
                        df = pd.read_excel(file_path, engine='openpyxl')
                        df['time'] = df['time'].round(0)  # Round 'time' to 0 decimal places
                        total_rows_before_merge += len(df)  # Add row count of current file
                        if subfolder_name not in data_dict:
                            data_dict[subfolder_name] = []
                        data_dict[subfolder_name].append(df)

                        # Count rows for EEG_handled subfolders
                        if folder == "EEG_handled":
                            if subfolder_name not in eeg_row_counts:
                                eeg_row_counts[subfolder_name] = 0
                            eeg_row_counts[subfolder_name] += len(df)
                    except Exception as e:
                        print(f"Error reading {file_path}: {e}")

    print(f"Total rows before merging for {subfolder_name}: {total_rows_before_merge}")

    # Print EEG row counts before merging
    for subfolder, row_count in eeg_row_counts.items():
        print(f"Rows in EEG_handled subfolder {subfolder}: {row_count}")

    # Merge DataFrames in each subfolder using 'time' and 'label' as keys
    merged_data = []
    for key, dfs in data_dict.items():
        print(f"Merging data for folder: {key}")
        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df, on=['time', 'label'], how='inner')
        merged_data.append(merged_df)
        print(f"Data shape after merging {key}: {merged_df.shape}")

    # Concatenate all merged DataFrames vertically
    final_df = pd.concat(merged_data, axis=0, ignore_index=True)

    # Drop the 'time' column
    final_df = final_df.drop(columns=['time'])

    # Fill NaN values with 0
    final_df = final_df.fillna(0)

    # Log the final shape
    print(f"Final data shape for {subfolder_name}: {final_df.shape}")
    total_rows_after_merge = len(final_df)
    print(f"Total rows after merging for {subfolder_name}: {total_rows_after_merge}")

    # Save the final DataFrame to a new Excel file
    final_output_path = os.path.join(merge_output_dir, f"{subfolder_name}_merged_data.xlsx")
    final_df.to_excel(final_output_path, index=False)

    # Output the path to the final merged file
    print(f"Final merged file saved to: {final_output_path}")

# Get all subfolder names from EEG_handled
eeg_handled_path = os.path.join(base_dir, "EEG_handled")
subfolders = [name for name in os.listdir(eeg_handled_path) if os.path.isdir(os.path.join(eeg_handled_path, name))]

# Merge data for each subfolder
for subfolder_name in subfolders:
    merge_data_for_subfolder(subfolder_name)
# Out:
# Error reading E:\IEEE Sensor\IEEE Sensor Xlsx Data\EEG_handled\21087_handled\~$Clean Data Channel 1_CUsersvhor0002DownloadsCODE BACK UP-20240215T015228Z-001CODE BACK UPRaw Data2108721087_8-07-2021 11_00_28.8 PM_ UCO at 953AM.xlsx: File is not a zip file
# Total rows before merging for 21087_handled: 450
# Rows in EEG_handled subfolder 21087_handled: 150
# Merging data for folder: 21087_handled
# Data shape after merging 21087_handled: (150, 36)
# Final data shape for 21087_handled: (150, 35)
# Total rows after merging for 21087_handled: 150
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21087_handled_merged_data.xlsx
# Total rows before merging for 20105_handled: 378
# Rows in EEG_handled subfolder 20105_handled: 126
# Merging data for folder: 20105_handled
# Data shape after merging 20105_handled: (126, 36)
# Final data shape for 20105_handled: (126, 35)
# Total rows after merging for 20105_handled: 126
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\20105_handled_merged_data.xlsx
# Total rows before merging for 21071_handled: 378
# Rows in EEG_handled subfolder 21071_handled: 126
# Merging data for folder: 21071_handled
# Data shape after merging 21071_handled: (126, 36)
# Final data shape for 21071_handled: (126, 35)
# Total rows after merging for 21071_handled: 126
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21071_handled_merged_data.xlsx
# Total rows before merging for 21122_handled: 423
# Rows in EEG_handled subfolder 21122_handled: 141
# Merging data for folder: 21122_handled
# Data shape after merging 21122_handled: (141, 36)
# Final data shape for 21122_handled: (141, 35)
# Total rows after merging for 21122_handled: 141
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21122_handled_merged_data.xlsx
# Total rows before merging for 21133_handled: 423
# Rows in EEG_handled subfolder 21133_handled: 141
# Merging data for folder: 21133_handled
# Data shape after merging 21133_handled: (141, 36)
# Final data shape for 21133_handled: (141, 35)
# Total rows after merging for 21133_handled: 141
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21133_handled_merged_data.xlsx
# Total rows before merging for 21173_handled: 387
# Rows in EEG_handled subfolder 21173_handled: 129
# Merging data for folder: 21173_handled
# Data shape after merging 21173_handled: (129, 36)
# Final data shape for 21173_handled: (129, 35)
# Total rows after merging for 21173_handled: 129
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21173_handled_merged_data.xlsx
# Total rows before merging for 21203_handled: 369
# Rows in EEG_handled subfolder 21203_handled: 123
# Merging data for folder: 21203_handled
# Data shape after merging 21203_handled: (123, 36)
# Final data shape for 21203_handled: (123, 35)
# Total rows after merging for 21203_handled: 123
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21203_handled_merged_data.xlsx
# Total rows before merging for 20244_handled: 450
# Rows in EEG_handled subfolder 20244_handled: 150
# Merging data for folder: 20244_handled
# Data shape after merging 20244_handled: (150, 36)
# Final data shape for 20244_handled: (150, 35)
# Total rows after merging for 20244_handled: 150
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\20244_handled_merged_data.xlsx
# Total rows before merging for 20252_handled: 432
# Rows in EEG_handled subfolder 20252_handled: 144
# Merging data for folder: 20252_handled
# Data shape after merging 20252_handled: (144, 36)
# Final data shape for 20252_handled: (144, 35)
# Total rows after merging for 20252_handled: 144
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\20252_handled_merged_data.xlsx
# Total rows before merging for 21200_handled: 333
# Rows in EEG_handled subfolder 21200_handled: 111
# Merging data for folder: 21200_handled
# Data shape after merging 21200_handled: (111, 36)
# Final data shape for 21200_handled: (111, 35)
# Total rows after merging for 21200_handled: 111
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21200_handled_merged_data.xlsx
# Total rows before merging for 21093_handled: 441
# Rows in EEG_handled subfolder 21093_handled: 147
# Merging data for folder: 21093_handled
# Data shape after merging 21093_handled: (147, 36)
# Final data shape for 21093_handled: (147, 35)
# Total rows after merging for 21093_handled: 147
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21093_handled_merged_data.xlsx
# Total rows before merging for 20112A_handled: 369
# Rows in EEG_handled subfolder 20112A_handled: 123
# Merging data for folder: 20112A_handled
# Data shape after merging 20112A_handled: (123, 36)
# Final data shape for 20112A_handled: (123, 35)
# Total rows after merging for 20112A_handled: 123
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\20112A_handled_merged_data.xlsx
# Total rows before merging for 21165_handled: 369
# Rows in EEG_handled subfolder 21165_handled: 123
# Merging data for folder: 21165_handled
# Data shape after merging 21165_handled: (123, 36)
# Final data shape for 21165_handled: (123, 35)
# Total rows after merging for 21165_handled: 123
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21165_handled_merged_data.xlsx
# Total rows before merging for 21044_handled: 540
# Rows in EEG_handled subfolder 21044_handled: 180
# Merging data for folder: 21044_handled
# Data shape after merging 21044_handled: (180, 36)
# Final data shape for 21044_handled: (180, 35)
# Total rows after merging for 21044_handled: 180
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21044_handled_merged_data.xlsx
# Total rows before merging for 21051_handled: 441
# Rows in EEG_handled subfolder 21051_handled: 147
# Merging data for folder: 21051_handled
# Data shape after merging 21051_handled: (147, 36)
# Final data shape for 21051_handled: (147, 35)
# Total rows after merging for 21051_handled: 147
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21051_handled_merged_data.xlsx
# Total rows before merging for 21126_handled: 402
# Rows in EEG_handled subfolder 21126_handled: 135
# Merging data for folder: 21126_handled
# Data shape after merging 21126_handled: (132, 36)
# Final data shape for 21126_handled: (132, 35)
# Total rows after merging for 21126_handled: 132
# Final merged file saved to: E:\IEEE Sensor\IEEE Sensor Xlsx Data\Merge_data\21126_handled_merged_data.xlsx
